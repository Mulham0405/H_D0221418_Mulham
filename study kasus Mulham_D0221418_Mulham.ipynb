# %%
#membuat program dengan syarat berikut
#program dapat menambahkan barang
#prgram dapat menghapus barang
#program dapat mengedit barang
#program dapat menampilkan barang
#program dapat mengetahui barang ada dalam list atau tidak
#program dapat menampilkan indeks tertentu

barang = []

while True :
  print('''Pilihan Operasi
  1. Menambah
  2. Menghapus
  3. Mengedit
  4. Menampilkan Barang
  5. Memeriksa Barang
  6. Mencari Indeks''')
  perintah = input("Masukkan Perintah :")

  if perintah == '1' :
    tmb = input("Masukkan Barang :")
    barang.append(tmb)
    print(barang)
    print("Apakah Program Masih Akan Berlanjut? ")
    kode = input("Ketik T untuk berhenti dan Y untuk lanjut : ")
    if kode == 'y' :
      print(barang)
    elif kode == 't' :
      break
    else :
      print("Periksa Masukan Anda!")
  elif perintah == '2' :
    hps = input("Masukkan Barang Yang Akan Dihapus :")
    barang.remove(hps)
    print(barang)
    print("Apakah Program Masih Akan Berlanjut? ")
    kode = input("Ketik T untuk berhenti dan Y untuk lanjut : ")
    if kode == 'y' :
      print(barang)
    elif kode == 't' :
      break
    else :
      print("Periksa Masukan Anda!")
  elif perintah == '3' :
    edit = input("Masukkan Barang Yang Akan Diedit :")
    index = None
    for i in range(len(barang)) : 
      if barang [i] == edit :
        index = i
    if index == None :
      print("Barang Tidak Ditemukan")
    else :
      barang[index] = input("Masukkan Barang Baru :")
    print(barang)
    print("Apakah Program Masih Akan Berlanjut? ")
    kode = input("Ketik T untuk berhenti dan Y untuk lanjut : ")
    if kode == 'y' :
      print(barang)
    elif kode == 't' :
      break
    else :
      print("Periksa Masukan Anda!")
  elif perintah == '4' :
    print(barang)
    print("Apakah Program Masih Akan Berlanjut? ")
    kode = input("Ketik T untuk berhenti dan Y untuk lanjut : ")
    if kode == 'y' :
      print(barang)
    elif kode == 't' :
      break
    else :
      print("Periksa Masukan Anda!")
  elif perintah == '5' :
    cari = input("Masukkan Barang Yang Akan Dicari : ")
    for i in range(len(barang)) :
      if barang[i] == cari :
        print("Barang Ditemukan")
      else :
        print("Barang Tidak Ditemukan")
    print(barang\)
    print("Apakah Program Masih Akan Berlanjut? ")
    kode = input("Ketik T untuk berhenti dan Y untuk lanjut : ")
    if kode == 'y' :
      print(barang)
    elif kode == 't' :
      break
    else :
      print("Periksa Masukan Anda!")
  elif perintah == '6' :
    cariindeks = input("Masukkan Barang Yang Akan Dicari Indeksnya : ")
    index = None
    for i in range(len(barang)) :
      if barang [i] == cariindeks :
        index = i
    if index == None :
      print("Barang Tidak Ditemukan")
    else :
      print("{} ada pada index ke {}". format(cariindeks, index))
    print(barang)
    print("Apakah Program Masih Akan Berlanjut? ")
    kode = input("Ketik T untuk berhenti dan Y untuk lanjut : ")
    if kode == 'y' :
      print(barang)
    elif kode == 't' :
      break
    else :
      print("Periksa Masukan Anda!")

  else :
    break

print("Program Berhenti. Good Bye")
print(barang)
# Out:
# Pilihan Operasi
#   1. Menambah
#   2. Menghapus
#   3. Mengedit
#   4. Menampilkan Barang
#   5. Memeriksa Barang
#   6. Mencari Indeks
# Masukkan Perintah :1
# Masukkan Barang :meja
# ['meja']
# Apakah Program Masih Akan Berlanjut?
# Ketik T untuk berhenti dan Y untuk lanjut : y
# ['meja']
# Pilihan Operasi
#   1. Menambah
#   2. Menghapus
#   3. Mengedit
#   4. Menampilkan Barang
#   5. Memeriksa Barang
#   6. Mencari Indeks
# Masukkan Perintah :5
# Masukkan Barang Yang Akan Dicari : meja
# Barang Ditemukan
# ['meja']
# Apakah Program Masih Akan Berlanjut?
# Ketik T untuk berhenti dan Y untuk lanjut : y
# ['meja']
# Pilihan Operasi
#   1. Menambah
#   2. Menghapus
#   3. Mengedit
#   4. Menampilkan Barang
#   5. Memeriksa Barang
#   6. Mencari Indeks
# Masukkan Perintah :1
# Masukkan Barang :kursi
# ['meja', 'kursi']
# Apakah Program Masih Akan Berlanjut?
# Ketik T untuk berhenti dan Y untuk lanjut : y
# ['meja', 'kursi']
# Pilihan Operasi
#   1. Menambah
#   2. Menghapus
# ...
